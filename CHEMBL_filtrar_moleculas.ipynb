# %% [markdown]
# <a href="https://colab.research.google.com/github/inefable12/herramientas_basicas/blob/main/CHEMBL_filtrar_moleculas.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# ## **Base de datos ChEMBL**

# %% [markdown]
# ## **Instalando librerías**

# %%
# !pip install chembl_webresource_client
# Out:
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# Collecting chembl_webresource_client
#   Downloading chembl_webresource_client-0.10.8-py3-none-any.whl (55 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 55.2/55.2 kB 5.7 MB/s eta 0:00:00
# Requirement already satisfied: urllib3 in /usr/local/lib/python3.10/dist-packages (from chembl_webresource_client) (1.26.15)
# Requirement already satisfied: requests>=2.18.4 in /usr/local/lib/python3.10/dist-packages (from chembl_webresource_client) (2.27.1)
# Collecting requests-cache~=0.7.0 (from chembl_webresource_client)
#   Downloading requests_cache-0.7.5-py3-none-any.whl (39 kB)
# Requirement already satisfied: easydict in /usr/local/lib/python3.10/dist-packages (from chembl_webresource_client) (1.10)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.10/dist-packages (from requests>=2.18.4->chembl_webresource_client) (2022.12.7)
# Requirement already satisfied: charset-normalizer~=2.0.0 in /usr/local/lib/python3.10/dist-packages (from requests>=2.18.4->chembl_webresource_client) (2.0.12)
# Requirement already satisfied: idna<4,>=2.5 in /usr/local/lib/python3.10/dist-packages (from requests>=2.18.4->chembl_webresource_client) (3.4)
# Collecting attrs<22.0,>=21.2 (from requests-cache~=0.7.0->chembl_webresource_client)
#   Downloading attrs-21.4.0-py2.py3-none-any.whl (60 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 60.6/60.6 kB 4.3 MB/s eta 0:00:00
# Requirement already satisfied: itsdangerous>=2.0.1 in /usr/local/lib/python3.10/dist-packages (from requests-cache~=0.7.0->chembl_webresource_client) (2.1.2)
# Requirement already satisfied: pyyaml>=5.4 in /usr/local/lib/python3.10/dist-packages (from requests-cache~=0.7.0->chembl_webresource_client) (6.0)
# Collecting url-normalize<2.0,>=1.4 (from requests-cache~=0.7.0->chembl_webresource_client)
#   Downloading url_normalize-1.4.3-py2.py3-none-any.whl (6.8 kB)
# Requirement already satisfied: six in /usr/local/lib/python3.10/dist-packages (from url-normalize<2.0,>=1.4->requests-cache~=0.7.0->chembl_webresource_client) (1.16.0)
# Installing collected packages: url-normalize, attrs, requests-cache, chembl_webresource_client
#   Attempting uninstall: attrs
#     Found existing installation: attrs 23.1.0
#     Uninstalling attrs-23.1.0:
#       Successfully uninstalled attrs-23.1.0
# Successfully installed attrs-21.4.0 chembl_webresource_client-0.10.8 requests-cache-0.7.5 url-normalize-1.4.3

# %% [markdown]
# ## **Importando librerías**

# %%
import pandas as pd
from chembl_webresource_client.new_client import new_client

# %% [markdown]
# ## **Búsqueda del target**

# %% [markdown]
# ### **Serotonine**

# %%
target = new_client.target
target_query = target.search('serotonine')
targets = pd.DataFrame.from_dict(target_query)
targets
# Out:
#                                      cross_references           organism  \
# 0   [{'xref_id': 'P31645', 'xref_name': None, 'xre...       Homo sapiens
# 1   [{'xref_id': 'P31652', 'xref_name': None, 'xre...  Rattus norvegicus
# 2   [{'xref_id': 'NBK23655', 'xref_name': 'Seroton...       Mus musculus
# 3   [{'xref_id': 'Q29495', 'xref_name': None, 'xre...         Ovis aries
# 4   [{'xref_id': 'Q9MYX0', 'xref_name': None, 'xre...     Macaca mulatta
# ..                                                ...                ...
# 92  [{'xref_id': 'P08909', 'xref_name': None, 'xre...  Rattus norvegicus
# 93                                                 []       Homo sapiens
# 94                                                 []       Homo sapiens
# 95                                                 []         Bos taurus
# 96                                                 []  Rattus norvegicus
#
#                                             pref_name  score  \
# 0                               Serotonin transporter    6.0
# 1                               Serotonin transporter    6.0
# 2                               Serotonin transporter    6.0
# 3                       Serotonin N-acetyltransferase    6.0
# 4                               Serotonin transporter    6.0
# ..                                                ...    ...
# 92                     Serotonin 2c (5-HT2c) receptor    3.0
# 93     Dopamine D2 receptor and serotonin 1a receptor    3.0
# 94                              Monoamine transporter    3.0
# 95                    5-hydroxytryptamine 1D receptor    3.0
# 96  Serotonin 1a (5-HT1a) receptor/Adrenergic rece...    2.0
#
#     species_group_flag target_chembl_id  \
# 0                False        CHEMBL228
# 1                False        CHEMBL313
# 2                False       CHEMBL4642
# 3                False       CHEMBL5452
# 4                False       CHEMBL5453
# ..                 ...              ...
# 92               False        CHEMBL324
# 93               False    CHEMBL2111460
# 94               False    CHEMBL2363064
# 95               False    CHEMBL3638336
# 96               False    CHEMBL2097171
#
#                                     target_components        target_type  \
# 0   [{'accession': 'P31645', 'component_descriptio...     SINGLE PROTEIN
# 1   [{'accession': 'P31652', 'component_descriptio...     SINGLE PROTEIN
# 2   [{'accession': 'Q60857', 'component_descriptio...     SINGLE PROTEIN
# 3   [{'accession': 'Q29495', 'component_descriptio...     SINGLE PROTEIN
# 4   [{'accession': 'Q9MYX0', 'component_descriptio...     SINGLE PROTEIN
# ..                                                ...                ...
# 92  [{'accession': 'P08909', 'component_descriptio...     SINGLE PROTEIN
# 93  [{'accession': 'P14416', 'component_descriptio...  SELECTIVITY GROUP
# 94  [{'accession': 'P31645', 'component_descriptio...     PROTEIN FAMILY
# 95  [{'accession': 'Q8MI13', 'component_descriptio...     SINGLE PROTEIN
# 96  [{'accession': 'P15823', 'component_descriptio...  SELECTIVITY GROUP
#
#     tax_id
# 0     9606
# 1    10116
# 2    10090
# 3     9940
# 4     9544
# ..     ...
# 92   10116
# 93    9606
# 94    9606
# 95    9913
# 96   10116
#
# [97 rows x 9 columns]

# %% [markdown]
# ### **Seleccionando y extrayendo la data de bioactividad**

# %%
selected_target = targets.target_chembl_id[0]
selected_target
# Out:
# 'CHEMBL228'

# %% [markdown]
# Obteniendo la data de bioactividad y cargándola en DataFrame

# %%
activity = new_client.activity
res = activity.filter(target_chembl_id=selected_target).filter(standard_type="IC50")

# %%
df = pd.DataFrame.from_dict(res)

# %%
df
# Out:
#                                             action_type activity_comment  \
# 0                                                  None             None
# 1                                                  None             None
# 2                                                  None             None
# 3                                                  None             None
# 4                                                  None             None
# ...                                                 ...              ...
# 4525  {'action_type': 'INHIBITOR', 'description': 'N...             None
# 4526                                               None             None
# 4527                                               None             None
# 4528  {'action_type': 'INHIBITOR', 'description': 'N...             None
# 4529  {'action_type': 'INHIBITOR', 'description': 'N...             None
#
#       activity_id                                activity_properties  \
# 0          105351                                                 []
# 1          105826                                                 []
# 2          106988                                                 []
# 3          108742                                                 []
# 4          111537                                                 []
# ...           ...                                                ...
# 4525     24917672                                                 []
# 4526     24917673                                                 []
# 4527     24957163  [{'comments': None, 'relation': None, 'result_...
# 4528     24963356                                                 []
# 4529     24963357                                                 []
#
#      assay_chembl_id                                  assay_description  \
# 0       CHEMBL806861  Inhibition of [3H]citalopram binding to seroto...
# 1       CHEMBL808141  Binding affinity towards serotonin transporter...
# 2       CHEMBL873260  Binding affinity towards serotonin transporter...
# 3       CHEMBL806861  Inhibition of [3H]citalopram binding to seroto...
# 4       CHEMBL806861  Inhibition of [3H]citalopram binding to seroto...
# ...              ...                                                ...
# 4525   CHEMBL5165150  Inhibition of SERT (unknown origin) expressed ...
# 4526   CHEMBL5165150  Inhibition of SERT (unknown origin) expressed ...
# 4527   CHEMBL5214042  Selectivity interaction (Enzyme and Receptor p...
# 4528   CHEMBL5216433                Inhibition of SERT (unknown origin)
# 4529   CHEMBL5216433                Inhibition of SERT (unknown origin)
#
#      assay_type assay_variant_accession assay_variant_mutation bao_endpoint  \
# 0             B                    None                   None  BAO_0000190
# 1             B                    None                   None  BAO_0000190
# 2             B                    None                   None  BAO_0000190
# 3             B                    None                   None  BAO_0000190
# 4             B                    None                   None  BAO_0000190
# ...         ...                     ...                    ...          ...
# 4525          B                    None                   None  BAO_0000190
# 4526          B                    None                   None  BAO_0000190
# 4527          B                    None                   None  BAO_0000190
# 4528          B                    None                   None  BAO_0000190
# 4529          B                    None                   None  BAO_0000190
#
#       ... target_organism       target_pref_name target_tax_id text_value  \
# 0     ...    Homo sapiens  Serotonin transporter          9606       None
# 1     ...    Homo sapiens  Serotonin transporter          9606       None
# 2     ...    Homo sapiens  Serotonin transporter          9606       None
# 3     ...    Homo sapiens  Serotonin transporter          9606       None
# 4     ...    Homo sapiens  Serotonin transporter          9606       None
# ...   ...             ...                    ...           ...        ...
# 4525  ...    Homo sapiens  Serotonin transporter          9606       None
# 4526  ...    Homo sapiens  Serotonin transporter          9606       None
# 4527  ...    Homo sapiens  Serotonin transporter          9606       None
# 4528  ...    Homo sapiens  Serotonin transporter          9606       None
# 4529  ...    Homo sapiens  Serotonin transporter          9606       None
#
#       toid  type units    uo_units upper_value   value
# 0     None  IC50    nM  UO_0000065        None  5160.0
# 1     None  IC50    nM  UO_0000065        None    1.15
# 2     None  IC50    nM  UO_0000065        None     4.2
# 3     None  IC50    nM  UO_0000065        None    33.4
# 4     None  IC50    nM  UO_0000065        None    27.6
# ...    ...   ...   ...         ...         ...     ...
# 4525  None  IC50    nM  UO_0000065        None   45.83
# 4526  None  IC50    nM  UO_0000065        None   100.0
# 4527  None  IC50    nM  UO_0000065        None    13.0
# 4528  None  IC50    nM  UO_0000065        None     6.0
# 4529  None  IC50    nM  UO_0000065        None    42.0
#
# [4530 rows x 46 columns]

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 4530 entries, 0 to 4529
# Data columns (total 46 columns):
#  #   Column                     Non-Null Count  Dtype
# ---  ------                     --------------  -----
#  0   action_type                105 non-null    object
#  1   activity_comment           1101 non-null   object
#  2   activity_id                4530 non-null   int64
#  3   activity_properties        4530 non-null   object
#  4   assay_chembl_id            4530 non-null   object
#  5   assay_description          4530 non-null   object
#  6   assay_type                 4530 non-null   object
#  7   assay_variant_accession    20 non-null     object
#  8   assay_variant_mutation     20 non-null     object
#  9   bao_endpoint               4530 non-null   object
#  10  bao_format                 4530 non-null   object
#  11  bao_label                  4530 non-null   object
#  12  canonical_smiles           4469 non-null   object
#  13  data_validity_comment      50 non-null     object
#  14  data_validity_description  50 non-null     object
#  15  document_chembl_id         4530 non-null   object
#  16  document_journal           3493 non-null   object
#  17  document_year              3658 non-null   float64
#  18  ligand_efficiency          3052 non-null   object
#  19  molecule_chembl_id         4530 non-null   object
#  20  molecule_pref_name         1120 non-null   object
#  21  parent_molecule_chembl_id  4530 non-null   object
#  22  pchembl_value              3149 non-null   object
#  23  potential_duplicate        4530 non-null   int64
#  24  qudt_units                 3610 non-null   object
#  25  record_id                  4530 non-null   int64
#  26  relation                   3592 non-null   object
#  27  src_id                     4530 non-null   int64
#  28  standard_flag              4530 non-null   int64
#  29  standard_relation          3592 non-null   object
#  30  standard_text_value        0 non-null      object
#  31  standard_type              4530 non-null   object
#  32  standard_units             3611 non-null   object
#  33  standard_upper_value       0 non-null      object
#  34  standard_value             3593 non-null   object
#  35  target_chembl_id           4530 non-null   object
#  36  target_organism            4530 non-null   object
#  37  target_pref_name           4530 non-null   object
#  38  target_tax_id              4530 non-null   object
#  39  text_value                 0 non-null      object
#  40  toid                       0 non-null      object
#  41  type                       4530 non-null   object
#  42  units                      3504 non-null   object
#  43  uo_units                   3610 non-null   object
#  44  upper_value                0 non-null      object
#  45  value                      3593 non-null   object
# dtypes: float64(1), int64(5), object(40)
# memory usage: 1.6+ MB

# %%
df.shape
# Out:
# (4530, 46)

# %% [markdown]
# Guardando en **bioactivity_data.csv**.

# %%
df.to_csv('bioactivity_data_raw.csv', index=False)

# %% [markdown]
# ## **Datos perdidos**
# Si hay datos perdidos en las columnas **standard_value** y **canonical_smiles** estos son dropeados.

# %%
df2 = df[df.standard_value.notna()]
df2 = df2[df.canonical_smiles.notna()]
df2
# Out:
# <ipython-input-12-955aac5800f0>:2: UserWarning: Boolean Series key will be reindexed to match DataFrame index.
#   df2 = df2[df.canonical_smiles.notna()]
#                                             action_type activity_comment  \
# 0                                                  None             None
# 1                                                  None             None
# 2                                                  None             None
# 3                                                  None             None
# 4                                                  None             None
# ...                                                 ...              ...
# 4525  {'action_type': 'INHIBITOR', 'description': 'N...             None
# 4526                                               None             None
# 4527                                               None             None
# 4528  {'action_type': 'INHIBITOR', 'description': 'N...             None
# 4529  {'action_type': 'INHIBITOR', 'description': 'N...             None
#
#       activity_id                                activity_properties  \
# 0          105351                                                 []
# 1          105826                                                 []
# 2          106988                                                 []
# 3          108742                                                 []
# 4          111537                                                 []
# ...           ...                                                ...
# 4525     24917672                                                 []
# 4526     24917673                                                 []
# 4527     24957163  [{'comments': None, 'relation': None, 'result_...
# 4528     24963356                                                 []
# 4529     24963357                                                 []
#
#      assay_chembl_id                                  assay_description  \
# 0       CHEMBL806861  Inhibition of [3H]citalopram binding to seroto...
# 1       CHEMBL808141  Binding affinity towards serotonin transporter...
# 2       CHEMBL873260  Binding affinity towards serotonin transporter...
# 3       CHEMBL806861  Inhibition of [3H]citalopram binding to seroto...
# 4       CHEMBL806861  Inhibition of [3H]citalopram binding to seroto...
# ...              ...                                                ...
# 4525   CHEMBL5165150  Inhibition of SERT (unknown origin) expressed ...
# 4526   CHEMBL5165150  Inhibition of SERT (unknown origin) expressed ...
# 4527   CHEMBL5214042  Selectivity interaction (Enzyme and Receptor p...
# 4528   CHEMBL5216433                Inhibition of SERT (unknown origin)
# 4529   CHEMBL5216433                Inhibition of SERT (unknown origin)
#
#      assay_type assay_variant_accession assay_variant_mutation bao_endpoint  \
# 0             B                    None                   None  BAO_0000190
# 1             B                    None                   None  BAO_0000190
# 2             B                    None                   None  BAO_0000190
# 3             B                    None                   None  BAO_0000190
# 4             B                    None                   None  BAO_0000190
# ...         ...                     ...                    ...          ...
# 4525          B                    None                   None  BAO_0000190
# 4526          B                    None                   None  BAO_0000190
# 4527          B                    None                   None  BAO_0000190
# 4528          B                    None                   None  BAO_0000190
# 4529          B                    None                   None  BAO_0000190
#
#       ... target_organism       target_pref_name target_tax_id text_value  \
# 0     ...    Homo sapiens  Serotonin transporter          9606       None
# 1     ...    Homo sapiens  Serotonin transporter          9606       None
# 2     ...    Homo sapiens  Serotonin transporter          9606       None
# 3     ...    Homo sapiens  Serotonin transporter          9606       None
# 4     ...    Homo sapiens  Serotonin transporter          9606       None
# ...   ...             ...                    ...           ...        ...
# 4525  ...    Homo sapiens  Serotonin transporter          9606       None
# 4526  ...    Homo sapiens  Serotonin transporter          9606       None
# 4527  ...    Homo sapiens  Serotonin transporter          9606       None
# 4528  ...    Homo sapiens  Serotonin transporter          9606       None
# 4529  ...    Homo sapiens  Serotonin transporter          9606       None
#
#       toid  type units    uo_units upper_value   value
# 0     None  IC50    nM  UO_0000065        None  5160.0
# 1     None  IC50    nM  UO_0000065        None    1.15
# 2     None  IC50    nM  UO_0000065        None     4.2
# 3     None  IC50    nM  UO_0000065        None    33.4
# 4     None  IC50    nM  UO_0000065        None    27.6
# ...    ...   ...   ...         ...         ...     ...
# 4525  None  IC50    nM  UO_0000065        None   45.83
# 4526  None  IC50    nM  UO_0000065        None   100.0
# 4527  None  IC50    nM  UO_0000065        None    13.0
# 4528  None  IC50    nM  UO_0000065        None     6.0
# 4529  None  IC50    nM  UO_0000065        None    42.0
#
# [3563 rows x 46 columns]

# %%
df2.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 3563 entries, 0 to 4529
# Data columns (total 46 columns):
#  #   Column                     Non-Null Count  Dtype
# ---  ------                     --------------  -----
#  0   action_type                105 non-null    object
#  1   activity_comment           164 non-null    object
#  2   activity_id                3563 non-null   int64
#  3   activity_properties        3563 non-null   object
#  4   assay_chembl_id            3563 non-null   object
#  5   assay_description          3563 non-null   object
#  6   assay_type                 3563 non-null   object
#  7   assay_variant_accession    20 non-null     object
#  8   assay_variant_mutation     20 non-null     object
#  9   bao_endpoint               3563 non-null   object
#  10  bao_format                 3563 non-null   object
#  11  bao_label                  3563 non-null   object
#  12  canonical_smiles           3563 non-null   object
#  13  data_validity_comment      50 non-null     object
#  14  data_validity_description  50 non-null     object
#  15  document_chembl_id         3563 non-null   object
#  16  document_journal           3306 non-null   object
#  17  document_year              3471 non-null   float64
#  18  ligand_efficiency          3022 non-null   object
#  19  molecule_chembl_id         3563 non-null   object
#  20  molecule_pref_name         338 non-null    object
#  21  parent_molecule_chembl_id  3563 non-null   object
#  22  pchembl_value              3119 non-null   object
#  23  potential_duplicate        3563 non-null   int64
#  24  qudt_units                 3562 non-null   object
#  25  record_id                  3563 non-null   int64
#  26  relation                   3562 non-null   object
#  27  src_id                     3563 non-null   int64
#  28  standard_flag              3563 non-null   int64
#  29  standard_relation          3562 non-null   object
#  30  standard_text_value        0 non-null      object
#  31  standard_type              3563 non-null   object
#  32  standard_units             3563 non-null   object
#  33  standard_upper_value       0 non-null      object
#  34  standard_value             3563 non-null   object
#  35  target_chembl_id           3563 non-null   object
#  36  target_organism            3563 non-null   object
#  37  target_pref_name           3563 non-null   object
#  38  target_tax_id              3563 non-null   object
#  39  text_value                 0 non-null      object
#  40  toid                       0 non-null      object
#  41  type                       3563 non-null   object
#  42  units                      3456 non-null   object
#  43  uo_units                   3562 non-null   object
#  44  upper_value                0 non-null      object
#  45  value                      3563 non-null   object
# dtypes: float64(1), int64(5), object(40)
# memory usage: 1.3+ MB

# %%
len(df2.canonical_smiles.unique())
# Out:
# 3080

# %%
df2_nr = df2.drop_duplicates(['canonical_smiles'])
df2_nr.head()
# Out:
#   action_type activity_comment  activity_id activity_properties  \
# 0        None             None       105351                  []
# 1        None             None       105826                  []
# 2        None             None       106988                  []
# 3        None             None       108742                  []
# 4        None             None       111537                  []
#
#   assay_chembl_id                                  assay_description  \
# 0    CHEMBL806861  Inhibition of [3H]citalopram binding to seroto...
# 1    CHEMBL808141  Binding affinity towards serotonin transporter...
# 2    CHEMBL873260  Binding affinity towards serotonin transporter...
# 3    CHEMBL806861  Inhibition of [3H]citalopram binding to seroto...
# 4    CHEMBL806861  Inhibition of [3H]citalopram binding to seroto...
#
#   assay_type assay_variant_accession assay_variant_mutation bao_endpoint  ...  \
# 0          B                    None                   None  BAO_0000190  ...
# 1          B                    None                   None  BAO_0000190  ...
# 2          B                    None                   None  BAO_0000190  ...
# 3          B                    None                   None  BAO_0000190  ...
# 4          B                    None                   None  BAO_0000190  ...
#
#   target_organism       target_pref_name target_tax_id text_value  toid  type  \
# 0    Homo sapiens  Serotonin transporter          9606       None  None  IC50
# 1    Homo sapiens  Serotonin transporter          9606       None  None  IC50
# 2    Homo sapiens  Serotonin transporter          9606       None  None  IC50
# 3    Homo sapiens  Serotonin transporter          9606       None  None  IC50
# 4    Homo sapiens  Serotonin transporter          9606       None  None  IC50
#
#   units    uo_units upper_value   value
# 0    nM  UO_0000065        None  5160.0
# 1    nM  UO_0000065        None    1.15
# 2    nM  UO_0000065        None     4.2
# 3    nM  UO_0000065        None    33.4
# 4    nM  UO_0000065        None    27.6
#
# [5 rows x 46 columns]

# %% [markdown]
# ## **Pre-procesamiento de los datos de bioactividad**

# %% [markdown]
# ### **Combinar las 3 columnas (molecule_chembl_id,canonical_smiles,standard_value) y bioactivity_class en el DataFrame**

# %%
selection = ['molecule_chembl_id','canonical_smiles','standard_value']
df3 = df2_nr[selection]
df3.head()
# Out:
#   molecule_chembl_id                                 canonical_smiles  \
# 0       CHEMBL322923           COC(=O)C1=C(c2ccc(Cl)c(Cl)c2)CC2CCC1C2
# 1       CHEMBL435341   C/C=C\c1ccc([C@H]2CC3CCC([C@H]2C(=O)OC)N3C)cc1
# 2       CHEMBL311347  COC(=O)[C@@H]1C2CC[C@H](C[C@@H]1c1ccc(I)cc1)N2C
# 3       CHEMBL100941            COC(=O)C1C2CCC(C2)CC1c1ccc(Cl)c(Cl)c1
# 4        CHEMBL87031           COC(=O)C1C(c2ccc(Cl)c(Cl)c2)CC2CCC1N2C
#
#   standard_value
# 0         5160.0
# 1           1.15
# 2            4.2
# 3           33.4
# 4           27.6

# %% [markdown]
# Guardar dataframe como arvhico CSV

# %%
df3.to_csv('Bioactivity_data_preprocessed.csv', index=False)

# %% [markdown]
# ### **Etiquetando compuestos como activos, inactivos o intermedios**
# La bioactividad se encuentra en unidades de IC50. Los compuestos teniendo valores menores que 1000 nM serán consideradas **active** mientas que mayores a 10 000 nM serán considerados como **inactive**. Valores entre 1,000 y 10,000 nM serán etiquetados como **intermediate**.

# %%
df4 = pd.read_csv('Bioactivity_data_preprocessed.csv')

# %%
bioactivity_threshold = []
for i in df4.standard_value:
  if float(i) >= 10000:
    bioactivity_threshold.append("inactive")
  elif float(i) <= 1000:
    bioactivity_threshold.append("active")
  else:
    bioactivity_threshold.append("intermediate")

# %%
bioactivity_class = pd.Series(bioactivity_threshold, name='class')
df5 = pd.concat([df4, bioactivity_class], axis=1)
df5
# Out:
#      molecule_chembl_id                                   canonical_smiles  \
# 0          CHEMBL322923             COC(=O)C1=C(c2ccc(Cl)c(Cl)c2)CC2CCC1C2
# 1          CHEMBL435341     C/C=C\c1ccc([C@H]2CC3CCC([C@H]2C(=O)OC)N3C)cc1
# 2          CHEMBL311347    COC(=O)[C@@H]1C2CC[C@H](C[C@@H]1c1ccc(I)cc1)N2C
# 3          CHEMBL100941              COC(=O)C1C2CCC(C2)CC1c1ccc(Cl)c(Cl)c1
# 4           CHEMBL87031             COC(=O)C1C(c2ccc(Cl)c(Cl)c2)CC2CCC1N2C
# ...                 ...                                                ...
# 3075      CHEMBL5180815  CCCCCc1nc(C2CCN(CCCCc3cn(C)c4ccc(C#N)cc34)CC2)...
# 3076      CHEMBL5200156  CCCCCc1nc(C2CCN(CCCCc3cn(CC)c4ccc(C#N)cc34)CC2...
# 3077      CHEMBL5204395  CCCCCc1nc(C2CCN(CCCCc3cn(CCC)c4ccc(C#N)cc34)CC...
# 3078      CHEMBL5178292  CCCCCc1nc(C2CCN(CCCCc3cn(C(C)C)c4ccc(C#N)cc34)...
# 3079      CHEMBL3609749  COc1cc(-c2cn([C@H]3CCc4c(F)cccc4N(CC(F)(F)F)C3...
#
#       standard_value         class
# 0            5160.00  intermediate
# 1               1.15        active
# 2               4.20        active
# 3              33.40        active
# 4              27.60        active
# ...              ...           ...
# 3075           15.05        active
# 3076           41.58        active
# 3077           45.83        active
# 3078          100.00        active
# 3079           13.00        active
#
# [3080 rows x 4 columns]

# %% [markdown]
# Saves dataframe to CSV file

# %%
df5.to_csv('Bioactivity_data_curated.csv', index=False)

# %%
! zip Bioactividad_df5.zip *.csv
# Out:
#   adding: Bioactivity_data_curated.csv (deflated 82%)
#   adding: Bioactivity_data_preprocessed.csv (deflated 81%)
#   adding: bioactivity_data_raw.csv (deflated 91%)

# %% [markdown]
# ---
